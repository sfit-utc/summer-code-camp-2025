# %%
import pandas as pd

# %%
df = pd.read_csv("students.csv")

print(df)
# Out:
#     ID               Name  Mark  Sex   Age
# 0   27  Nguyen Minh Hoang   NaN  Nam  21.0
# 1   90     Dinh Khac Manh   NaN  NaN   NaN
# 2   78      Dinh Duy Hung   NaN  NaN  23.0
# 3    2    Nguyen Minh Anh   5.0   Nu  23.0
# 4   20      Tran Duc Manh   8.0  Nam   NaN
# ..  ..                ...   ...  ...   ...
# 95  93      Le Tuan Trang   7.0  Nam  21.0
# 96  87      Luong Van Anh   3.0   Nu  19.0
# 97  45   Luong Minh Trang   NaN  NaN  21.0
# 98  83    Hoang Khac Dung   1.0  NaN  23.0
# 99  52    Nguyen Duy Dung  10.0   Nu  24.0
#
# [100 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      100 non-null    int64
#  1   Name    100 non-null    object
#  2   Mark    43 non-null     float64
#  3   Sex     74 non-null     object
#  4   Age     52 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 4.0+ KB

# %%
df[['Name', 'Mark']]
# Out:
#                  Name  Mark
# 0   Nguyen Minh Hoang   NaN
# 1      Dinh Khac Manh   NaN
# 2       Dinh Duy Hung   NaN
# 3     Nguyen Minh Anh   5.0
# 4       Tran Duc Manh   8.0
# ..                ...   ...
# 95      Le Tuan Trang   7.0
# 96      Luong Van Anh   3.0
# 97   Luong Minh Trang   NaN
# 98    Hoang Khac Dung   1.0
# 99    Nguyen Duy Dung  10.0
#
# [100 rows x 2 columns]

# %%
df[0: 10]
# Out:
#    ID               Name  Mark  Sex   Age
# 0  27  Nguyen Minh Hoang   NaN  Nam  21.0
# 1  90     Dinh Khac Manh   NaN  NaN   NaN
# 2  78      Dinh Duy Hung   NaN  NaN  23.0
# 3   2    Nguyen Minh Anh   5.0   Nu  23.0
# 4  20      Tran Duc Manh   8.0  Nam   NaN
# 5  70       Le Van Trang   NaN   Nu  19.0
# 6  75       Le Khac Manh   8.0  NaN   NaN
# 7  91      Tran Thi Hang   2.0  Nam  25.0
# 8  67      Pham Duy Dung   NaN  NaN  24.0
# 9  17      Pham Duy Dung   NaN   Nu  24.0

# %%
df[df['Sex'] == 'Nam']
# Out:
#     ID               Name  Mark  Sex   Age
# 0   27  Nguyen Minh Hoang   NaN  Nam  21.0
# 4   20      Tran Duc Manh   8.0  Nam   NaN
# 7   91      Tran Thi Hang   2.0  Nam  25.0
# 13  59   Nguyen Duy Hoang   NaN  Nam  25.0
# 14  97    Tran Tuan Trang   NaN  Nam  21.0
# 16  65   Hoang Minh Trang   NaN  Nam  19.0
# 18  18  Nguyen Minh Hoang   NaN  Nam   NaN
# 20  68     Dinh Khac Hang   2.0  Nam   NaN
# 23  14      Tran Duc Hang   NaN  Nam  21.0
# 25  94     Tran Khac Hung   1.0  Nam  18.0
# 27  13    Hoang Duy Trang   NaN  Nam  20.0
# 29  56     Hoang Thi Hung   1.0  Nam   NaN
# 34  36       Pham Van Anh   NaN  Nam  22.0
# 41  44    Hoang Duc Hoang   5.0  Nam  18.0
# 42  98     Hoang Van Dung   NaN  Nam  21.0
# 44  54     Hoang Duy Hung   NaN  Nam  25.0
# 49  61      Le Minh Hoang   NaN  Nam   NaN
# 50  19    Hoang Duy Trang   NaN  Nam   NaN
# 51   7      Le Minh Trang   8.0  Nam  18.0
# 52  49      Tran Duc Hien   4.0  Nam   NaN
# 55  62  Nguyen Tuan Trang   NaN  Nam   NaN
# ...

# %%
df2 = df[(df['Sex'] == 'Nam') & (df['Mark'] > 5.0)]

print(df2)
# Out:
#     ID               Name  Mark  Sex   Age
# 4   20      Tran Duc Manh   8.0  Nam   NaN
# 51   7      Le Minh Trang   8.0  Nam  18.0
# 56  37    Dinh Khac Hoang   7.0  Nam   NaN
# 64  95   Nguyen Minh Hien   8.0  Nam   NaN
# 86  88      Tran Duy Manh   8.0  Nam  19.0
# 91   5    Nguyen Duy Hien  10.0  Nam   NaN
# 94  43  Nguyen Khac Hoang   9.0  Nam  25.0
# 95  93      Le Tuan Trang   7.0  Nam  21.0

# %%
df2.to_csv("students2.csv")

# %%
def ()

# %%
df['Pass'] = df['Mark'].apply(lambda x: "Chua biet" if pd.isna(x) else ('Yes' if x > 4.0 else 'No'))

# %%
df
# Out:
#     ID               Name  Mark  Sex   Age       Pass
# 0   27  Nguyen Minh Hoang   NaN  Nam  21.0  Chua biet
# 1   90     Dinh Khac Manh   NaN  NaN   NaN  Chua biet
# 2   78      Dinh Duy Hung   NaN  NaN  23.0  Chua biet
# 3    2    Nguyen Minh Anh   5.0   Nu  23.0        Yes
# 4   20      Tran Duc Manh   8.0  Nam   NaN        Yes
# ..  ..                ...   ...  ...   ...        ...
# 95  93      Le Tuan Trang   7.0  Nam  21.0        Yes
# 96  87      Luong Van Anh   3.0   Nu  19.0         No
# 97  45   Luong Minh Trang   NaN  NaN  21.0  Chua biet
# 98  83    Hoang Khac Dung   1.0  NaN  23.0         No
# 99  52    Nguyen Duy Dung  10.0   Nu  24.0        Yes
#
# [100 rows x 6 columns]

# %%
df.drop(columns= ['Pass'])
# Out:
#     ID               Name  Mark  Sex   Age
# 0   27  Nguyen Minh Hoang   NaN  Nam  21.0
# 1   90     Dinh Khac Manh   NaN  NaN   NaN
# 2   78      Dinh Duy Hung   NaN  NaN  23.0
# 3    2    Nguyen Minh Anh   5.0   Nu  23.0
# 4   20      Tran Duc Manh   8.0  Nam   NaN
# ..  ..                ...   ...  ...   ...
# 95  93      Le Tuan Trang   7.0  Nam  21.0
# 96  87      Luong Van Anh   3.0   Nu  19.0
# 97  45   Luong Minh Trang   NaN  NaN  21.0
# 98  83    Hoang Khac Dung   1.0  NaN  23.0
# 99  52    Nguyen Duy Dung  10.0   Nu  24.0
#
# [100 rows x 5 columns]

# %%
df = df.drop(columns= ['Pass'])

# %%
print(df)
# Out:
#     ID               Name  Mark  Sex   Age
# 0   27  Nguyen Minh Hoang   NaN  Nam  21.0
# 1   90     Dinh Khac Manh   NaN  NaN   NaN
# 2   78      Dinh Duy Hung   NaN  NaN  23.0
# 3    2    Nguyen Minh Anh   5.0   Nu  23.0
# 4   20      Tran Duc Manh   8.0  Nam   NaN
# ..  ..                ...   ...  ...   ...
# 95  93      Le Tuan Trang   7.0  Nam  21.0
# 96  87      Luong Van Anh   3.0   Nu  19.0
# 97  45   Luong Minh Trang   NaN  NaN  21.0
# 98  83    Hoang Khac Dung   1.0  NaN  23.0
# 99  52    Nguyen Duy Dung  10.0   Nu  24.0
#
# [100 rows x 5 columns]

# %%
df.sort_values(by= ['Mark'])
# Out:
#     ID              Name  Mark  Sex   Age
# 26  47    Tran Minh Hang   0.0   Nu   NaN
# 71  84    Tran Duc Trang   0.0  NaN  18.0
# 72  79      Le Duy Hoang   0.0  NaN  19.0
# 29  56    Hoang Thi Hung   1.0  Nam   NaN
# 25  94    Tran Khac Hung   1.0  Nam  18.0
# ..  ..               ...   ...  ...   ...
# 85  46    Luong Van Hung   NaN  Nam   NaN
# 88  64     Luong Thi Anh   NaN  Nam   NaN
# 92  96      Le Minh Hung   NaN   Nu   NaN
# 93  77     Dinh Duc Hien   NaN  Nam   NaN
# 97  45  Luong Minh Trang   NaN  NaN  21.0
#
# [100 rows x 5 columns]

# %%
df.head(5)
# Out:
#    ID               Name  Mark  Sex   Age
# 0  27  Nguyen Minh Hoang   NaN  Nam  21.0
# 1  90     Dinh Khac Manh   NaN  NaN   NaN
# 2  78      Dinh Duy Hung   NaN  NaN  23.0
# 3   2    Nguyen Minh Anh   5.0   Nu  23.0
# 4  20      Tran Duc Manh   8.0  Nam   NaN

# %%
df.tail(8)
# Out:
#     ID               Name  Mark  Sex   Age
# 92  96       Le Minh Hung   NaN   Nu   NaN
# 93  77      Dinh Duc Hien   NaN  Nam   NaN
# 94  43  Nguyen Khac Hoang   9.0  Nam  25.0
# 95  93      Le Tuan Trang   7.0  Nam  21.0
# 96  87      Luong Van Anh   3.0   Nu  19.0
# 97  45   Luong Minh Trang   NaN  NaN  21.0
# 98  83    Hoang Khac Dung   1.0  NaN  23.0
# 99  52    Nguyen Duy Dung  10.0   Nu  24.0

# %%
df.describe()
# Out:
#                ID       Mark        Age
# count  100.000000  43.000000  52.000000
# mean    50.500000   4.697674  21.634615
# std     29.011492   3.173813   2.401216
# min      1.000000   0.000000  18.000000
# 25%     25.750000   2.000000  19.000000
# 50%     50.500000   5.000000  22.000000
# 75%     75.250000   7.000000  24.000000
# max    100.000000  10.000000  25.000000

# %%
gr_df = df.groupby('Sex')

# %%
gr_df.plot.pie(subplots= True, figsize= (10, 10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 gr_df.plot.pie(subplots= True, figsize= (10, 10))
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:750, in GroupByPlot.__getattr__.<locals>.attr(*args, **kwargs)
#     747 def f(self):
#     748     return getattr(self.plot, name)(*args, **kwargs)
# --> 750 return self._groupby._python_apply_general(f, self._groupby._selected_obj)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1885, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1850 @final
#    1851 def _python_apply_general(
#    1852     self,
#    (...)
#    1857     is_agg: bool = False,
#    1858 ) -> NDFrameT:
#    1859     """
# ...

# %%
df['Mark'].plot.line(color= 'red')
# Out:
# <Axes: >

# %%
df['Mark'].isna().sum()
# Out:
# np.int64(57)

# %%
df['Mark'].isna().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df['Mark'].plot.line(color= 'red')
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:1130, in Series.__getitem__(self, key)
#    1127     return self._values[key]
#    1129 elif key_is_scalar:
# -> 1130     return self._get_value(key)
#    1132 # Convert generator to list before going through hashable part
#    1133 # (We will iterate through the generator there to check for slices)
#    1134 if is_iterator(key):
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:1246, in Series._get_value(self, label, takeable)
#    1243     return self._values[label]
#    1245 # Similar to Index.get_value, but we do not fall back to positional
# -> 1246 loc = self.index.get_loc(label)
# ...
